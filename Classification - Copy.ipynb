# %% [markdown]
# # Brain Tumor Detection
#
# ### By: [Ogunleye Toluwalashe](http://github.com/Toluwaa-o)
# ### Tools: TensorFlow, Python, Kaggle, Machine Learning, Neural Networks, e.t.c

# %% [markdown]
# First, import all the libraries we will be using in this project.

# %%
import os
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import models, layers
from skimage.transform import resize

random.seed(2)

# %% [markdown]
# # Data Fetching

# %% [markdown]
# The dataset contains two folders, 'train' and 'test'. We are going to store the 'train' path as a variable so we can use it in our function.

# %%
train_images_path = './train'

# %% [markdown]
# The train folder also contains two folders. The 'no' folder (for images that don't have a tumor) and the 'yes' folder for images that have a tumor. We are going to create a function to iterate over both folders and read all the images, while also storing the corresponding label (1: for yes and 0: for no). At the end of the function, we return the list containing our data.

# %%
def get_all_images(url):
    ds = []
    
    for cls in os.listdir(url):
        new_path = os.path.join(url, cls)
        for im in os.listdir(new_path):
            
            img_path = os.path.join(new_path, im)
            img = cv2.imread(img_path)
            
            # Reshape the images because the sizes are inconsistent
            resized_img = resize(img, (128, 128, 3))
            label = 1 if cls == 'yes' else 0
            ds.append((np.array(resized_img), label))
    return ds

# %% [markdown]
# Next, we call the funtion and store it in a variable called 'ds'

# %%
ds = get_all_images(train_images_path)

# %% [markdown]
# Next, we explore the length and shape of the data we received to make sure everything is stored properly.

# %%
len(ds), ds[0][0].shape
# Out:
# (7012, (128, 128, 3))

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Next, we shuffle the data to ensure there is an element of randomness in the data the model receives

# %%
np.random.shuffle(ds)

# %% [markdown]
# ### Splitting the data into training and validation data
#
# Next, we are going to get the total size of the data and then divide it 0.9-0.1. 0.9 for training and the remaining data for validation.

# %%
sample_size = len(ds)

train_size = int(0.9 * sample_size)
valid_size = sample_size - train_size

# %% [markdown]
# Next, we store our images and labels in separate variables

# %%
ds_images = [obv[0] for obv in ds]
ds_labels = np.array([obv[1] for obv in ds])

# %% [markdown]
# After that, we visualized the first 5 images in the dataset, just to visualize our data. We also set the label as the title.

# %%
for num in range(0,5):
    plt.imshow(ds_images[num])
    plt.title(ds_labels[num])
    plt.axis('off')
    plt.show()

# %% [markdown]
# Next, split the inputs and labels into different variables

# %%
train_imgs = ds_images[:train_size]
train_labels = ds_labels[:train_size]

valid_imgs = ds_images[train_size:]
valid_labels = ds_labels[train_size:]

# %% [markdown]
# We check the length of training and validation variables to make sure it was properly split 0.9-0.1.

# %%
len(train_labels), len(valid_imgs)
# Out:
# (6310, 702)

# %% [markdown]
# ### Caching the data, so we can feed it to the model in batches and thereby use less space
#
# Next steps include converting the dataset into a tensor dataset so we can cache it. After we have done that, we cache it in batches of 16.

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_imgs, train_labels))
valid_ds = tf.data.Dataset.from_tensor_slices((valid_imgs, valid_labels))

# %%
batch_size = 16

train_ds = train_ds.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)
valid_ds = valid_ds.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Model Creation
#
# Now that we are done preparing the data, we can now create our model.
# - The first layer in the model rescales the data, so that the values are between 0 and 1.
# - This model involves 3 convolutional layers. One depthwise convolutional layer and two regular convolutional layers.
# - The first regular convolutional layer applies 50 filters and the second one applies 25 filters
# - We use the 'relu' activation function in those layers.
# - It also includes two maxpooling layers, that use a 2/2 window when extracting information.
# - After all these layers, we flatten the data. Then the data passes through a dense layer with 25 neurons before the output layer
# - The output is binary so the output layer only expects 1 value

# %%
model = models.Sequential()
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(50, (3,3), activation="relu", strides=(2,2), padding='same', input_shape=(128, 128, 3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(25, (3,3), activation="relu"))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(1))
# Out:
# c:\Users\Owner\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %% [markdown]
# After creating the model architecture, we compile it.
# - We use the Adam optimizer, with a learning rate of 0.001
# - The binary crossentropy loss function (because we are dealing with binary output). From logits is also set to true so that it doesnt output probabilities
# - We also set accuracy as the metric because this is a classification problem.
# - After that we fit the model, and it runs for the preset number of epochs (50)

# %%
lr = 0.001

model.compile(
    optimizer=tf.keras.optimizers.Adam(lr),
    loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=['accuracy']
)

epochs = 50

model.fit(
    train_ds,
    epochs = epochs,
    validation_data = valid_ds,
    verbose = 2
)
# Out:
# Epoch 1/50
# 395/395 - 44s - 111ms/step - accuracy: 0.6055 - loss: 0.6024 - val_accuracy: 0.7550 - val_loss: 0.4381
# Epoch 2/50
# 395/395 - 17s - 43ms/step - accuracy: 0.8214 - loss: 0.4047 - val_accuracy: 0.8718 - val_loss: 0.3206
# Epoch 3/50
# 395/395 - 18s - 44ms/step - accuracy: 0.8727 - loss: 0.3240 - val_accuracy: 0.9031 - val_loss: 0.2717
# Epoch 4/50
# 395/395 - 17s - 43ms/step - accuracy: 0.8954 - loss: 0.2759 - val_accuracy: 0.8960 - val_loss: 0.2625
# Epoch 5/50
# 395/395 - 18s - 45ms/step - accuracy: 0.9051 - loss: 0.2469 - val_accuracy: 0.9217 - val_loss: 0.2328
# Epoch 6/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9125 - loss: 0.2269 - val_accuracy: 0.9217 - val_loss: 0.2286
# Epoch 7/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9192 - loss: 0.2098 - val_accuracy: 0.9245 - val_loss: 0.2225
# Epoch 8/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9268 - loss: 0.1943 - val_accuracy: 0.9373 - val_loss: 0.2015
# Epoch 9/50
# 395/395 - 18s - 44ms/step - accuracy: 0.9322 - loss: 0.1836 - val_accuracy: 0.9359 - val_loss: 0.2055
# Epoch 10/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9341 - loss: 0.1731 - val_accuracy: 0.9430 - val_loss: 0.1888
# Epoch 11/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9401 - loss: 0.1620 - val_accuracy: 0.9473 - val_loss: 0.1822
# Epoch 12/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9464 - loss: 0.1486 - val_accuracy: 0.9459 - val_loss: 0.1865
# Epoch 13/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9506 - loss: 0.1407 - val_accuracy: 0.9430 - val_loss: 0.1882
# Epoch 14/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9531 - loss: 0.1343 - val_accuracy: 0.9501 - val_loss: 0.1755
# Epoch 15/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9585 - loss: 0.1267 - val_accuracy: 0.9530 - val_loss: 0.1707
# Epoch 16/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9609 - loss: 0.1189 - val_accuracy: 0.9544 - val_loss: 0.1651
# Epoch 17/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9631 - loss: 0.1118 - val_accuracy: 0.9573 - val_loss: 0.1599
# Epoch 18/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9667 - loss: 0.1051 - val_accuracy: 0.9530 - val_loss: 0.1630
# Epoch 19/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9670 - loss: 0.1001 - val_accuracy: 0.9544 - val_loss: 0.1743
# Epoch 20/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9688 - loss: 0.0926 - val_accuracy: 0.9587 - val_loss: 0.1529
# Epoch 21/50
# 395/395 - 18s - 44ms/step - accuracy: 0.9716 - loss: 0.0858 - val_accuracy: 0.9558 - val_loss: 0.1636
# Epoch 22/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9739 - loss: 0.0818 - val_accuracy: 0.9587 - val_loss: 0.1545
# Epoch 23/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9748 - loss: 0.0774 - val_accuracy: 0.9601 - val_loss: 0.1616
# Epoch 24/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9767 - loss: 0.0715 - val_accuracy: 0.9615 - val_loss: 0.1633
# Epoch 25/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9784 - loss: 0.0668 - val_accuracy: 0.9644 - val_loss: 0.1482
# Epoch 26/50
# 395/395 - 18s - 46ms/step - accuracy: 0.9805 - loss: 0.0608 - val_accuracy: 0.9644 - val_loss: 0.1522
# Epoch 27/50
# 395/395 - 18s - 45ms/step - accuracy: 0.9813 - loss: 0.0591 - val_accuracy: 0.9644 - val_loss: 0.1466
# Epoch 28/50
# 395/395 - 22s - 55ms/step - accuracy: 0.9835 - loss: 0.0554 - val_accuracy: 0.9672 - val_loss: 0.1467
# Epoch 29/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9834 - loss: 0.0521 - val_accuracy: 0.9601 - val_loss: 0.1473
# Epoch 30/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9840 - loss: 0.0501 - val_accuracy: 0.9672 - val_loss: 0.1431
# Epoch 31/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9857 - loss: 0.0458 - val_accuracy: 0.9644 - val_loss: 0.1516
# Epoch 32/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9861 - loss: 0.0451 - val_accuracy: 0.9615 - val_loss: 0.1489
# Epoch 33/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9856 - loss: 0.0434 - val_accuracy: 0.9601 - val_loss: 0.1434
# Epoch 34/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9868 - loss: 0.0399 - val_accuracy: 0.9601 - val_loss: 0.1550
# Epoch 35/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9886 - loss: 0.0369 - val_accuracy: 0.9516 - val_loss: 0.1718
# Epoch 36/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9881 - loss: 0.0356 - val_accuracy: 0.9573 - val_loss: 0.1620
# Epoch 37/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9872 - loss: 0.0349 - val_accuracy: 0.9672 - val_loss: 0.1514
# Epoch 38/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9864 - loss: 0.0383 - val_accuracy: 0.9558 - val_loss: 0.1707
# Epoch 39/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9875 - loss: 0.0358 - val_accuracy: 0.9487 - val_loss: 0.1915
# Epoch 40/50
# 395/395 - 17s - 44ms/step - accuracy: 0.9897 - loss: 0.0306 - val_accuracy: 0.9487 - val_loss: 0.1963
# Epoch 41/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9894 - loss: 0.0314 - val_accuracy: 0.9601 - val_loss: 0.1866
# Epoch 42/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9913 - loss: 0.0276 - val_accuracy: 0.9558 - val_loss: 0.1852
# Epoch 43/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9908 - loss: 0.0276 - val_accuracy: 0.9459 - val_loss: 0.2049
# Epoch 44/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9892 - loss: 0.0297 - val_accuracy: 0.9558 - val_loss: 0.1958
# Epoch 45/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9924 - loss: 0.0234 - val_accuracy: 0.9487 - val_loss: 0.2040
# Epoch 46/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9919 - loss: 0.0226 - val_accuracy: 0.9630 - val_loss: 0.1821
# Epoch 47/50
# 395/395 - 17s - 42ms/step - accuracy: 0.9906 - loss: 0.0259 - val_accuracy: 0.9573 - val_loss: 0.1986
# Epoch 48/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9938 - loss: 0.0188 - val_accuracy: 0.9288 - val_loss: 0.2544
# Epoch 49/50
# 395/395 - 17s - 43ms/step - accuracy: 0.9922 - loss: 0.0193 - val_accuracy: 0.9644 - val_loss: 0.2029
# Epoch 50/50
# 395/395 - 18s - 45ms/step - accuracy: 0.9910 - loss: 0.0259 - val_accuracy: 0.9758 - val_loss: 0.1885

# %% [markdown]
# - After 50 Epochs, our model stops. We have a training accuracy of 99.95% and a loss of just 0.0025. This is very good.
# - To make sure our model didn't just overfit, we check the validation details as well
# - We have a validation accuracy of 97.9% and a loss of 0.1. This means our model overfitted by a little, but this is not a problem as the difference is not substancial.

# %% [markdown]
# Next, we save the model so we can access it later

# %%
model.save('Brain_Tumor_Model_2.keras')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Owner\AppData\Local\Temp\tmpnwibj1x_\assets
# INFO:tensorflow:Assets written to: C:\Users\Owner\AppData\Local\Temp\tmpnwibj1x_\assets
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Testing the Model
#
# The final step is to test our model, and the dataset already comes with training data so we are going to use that

# %% [markdown]
# We follow the steps we used in preprocessing the training data and we preprocess the test data as well.

# %%
model = tf.keras.models.load_model('Brain_Tumor_Model_2.keras')

# %%
#test_images = './test'

# %%
#test_images = get_all_images(test_images)

# %%
#test_imgs = [obv[0] for obv in test_images]
#test_labels = np.array([obv[1] for obv in test_images])

# %%
#batch_size = 16

#test_ds = tf.data.Dataset.from_tensor_slices((test_imgs, test_labels))
#test_ds = test_ds.cache().batch(batch_size).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# Now that preprocessing is done, we can finally test our model

# %%
#loss, accuracy = model.evaluate(test_ds)

# %% [markdown]
# After testing the model, we see that we have a test accuracy of 98.4% and a loss of 0.3.

# %% [markdown]
# In conclusion, the aim of this project was to create a model that could accurately tell us if a tumor is present in a person's brain through brain scan images and we have successfully done that. We have created a model that can classify brain tumor images with an accuracy of 98.4%!.
